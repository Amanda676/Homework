# %% [markdown]
# # Week 22

# %% [markdown]
# 1.	Create a python function to scrape Yelp data for 50 restaurants close to you. Think about what data you want to scrape aside from the restaurant name and location. You must pick at least three other fields. You can use beautiful soup, selenium, scrapy, and/or splinter.

# %%
#import what I think I'll need

from bs4 import BeautifulSoup as bs
import requests
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager
from scrapy import Selector
import time

import pandas as pd

# %%
# not sure I'm using this
# executable_path = {'executable_path':ChromeDriverManager().install()}
# browser = Browser('chrome',**executable_path, headless=False)

# %%
#url = "https://www.yelp.com/search?find_desc=Restaurants&find_loc=63040"

# %%
def scrape_urls():
    # function to get 50 restaurant urls
    # returns list of the 50 urls
    top_50_url = []
    for i in range(0, 50, 10):
        time.sleep(2)
        # url, with 10 restaurants at a time
        url = f'https://www.yelp.com/search?find_desc=Restaurants&find_loc=63040&start={i}'
        try:
            response = requests.get(url)
            soup = bs(response.text, 'html.parser')
            # get the top names
            ten_names = soup.find_all('span',class_="css-1pxmz4g")

            # first two and last parts of the list are ads, ignore
            for j in range(0, len(ten_names)):
                #get url to visit
                top_50_url.append(ten_names[j].a.get('href'))
        except AttributeError as e:
            print(e)
    
    return top_50_url

# %%
def get_rest_info(url_list):
    # takes list of urls to scrape on yelp
    # returns list of dictionaries with info
    
    top_50_url = url_list
    list50_restaurants = []
    #iterate over top_50_urls
    for i in range(0, len(top_50_url)):
        #add sleep function 
        time.sleep(3)
        
        #print progress every 5 visits
        if i%5 == 0:
            print("Visiting urls: ", str(i))
        
        # make urls
        url = f'https://www.yelp.com{top_50_url[i]}'

        try:
            response = requests.get(url)
            soup = bs(response.text, 'html.parser')
            sel = Selector(text = response.text)

            # order from yelp
            rank = i+1

            # get restaurant name
            name = soup.find('h1', class_="css-11q1g5y").text

            # get address
            try:
                address = soup.find('p', class_="css-chtywg").text
            except:
                address = ''

            #get number of stars with xpath, extract from list
            try:
                stars = sel.xpath \
                ('//*[@id="wrap"]/div[2]/yelp-react-root/div[1]/div[3]/div[1]/div[1]/div/div/div[2]/div[1]/span/div/@aria-label').extract()
                stars = stars[0]
            except:
                stars = ''

            # build category list
            category = []

            # number of reviews, text
            # exception for only 1 in the list
            try:
                cat_list = soup.find_all('span', class_="css-bq71j2")
                # if there is only one thing in the list, it's not number of reviews,
                # it's the category
                if len(cat_list) == 1:
                    num_reviews = 0
                    category.append(cat_list[0].a.text)
                else:
                    num_reviews = cat_list[0].text
            except:
                num_reviews = 0

            # find the categories listed for the restaurant
            try:
                for i in range(1, len(cat_list)):
                    category.append(cat_list[i].a.text)
            except:
                pass

            rest_dict = {"Rank": rank,
                        "Restaurant_Name": name,
                        "Address": address,
                        "Stars": stars,
                         "Number_Reviews": num_reviews,
                        "Category": category}
            list50_restaurants.append(rest_dict)

        except AttributeError as e:
            print(e)

    return list50_restaurants

# %%
yelp_urls = scrape_urls()

# %%
len(yelp_urls)
# Out:
# 50

# %%
yelp_info = get_rest_info(yelp_urls)
# Out:
# Visiting urls:  0
# Visiting urls:  5
# Visiting urls:  10
# Visiting urls:  15
# Visiting urls:  20
# Visiting urls:  25
# Visiting urls:  30
# Visiting urls:  35
# Visiting urls:  40
# Visiting urls:  45

# %%
yelp_df = pd.DataFrame(yelp_info)
yelp_df
# Out:
#     Rank                         Restaurant_Name  \
# 0      1                     Big Chief Roadhouse
# 1      2                     Benedetto's On Main
# 2      3                                   Craft
# 3      4                    Wildwood Pub & Grill
# 4      5    Malinche Mexican Culinary Experience
# 5      6                        Letty Lou's Cafe
# 6      7                         Parkside Grille
# 7      8                             Thai Bistro
# 8      9                         The Stellar Hog
# 9     10                                The Wolf
# 10    11                          Chick-N-Elly's
# 11    12                      Hola! Mexican Food
# 12    13                The Crafty Chameleon Bar
# 13    14                        Mulligan's Grill
# 14    15                The Corner Pub and Grill
# 15    16                       Wildwood BBQ Bash
# 16    17                               El Maguey
# 17    18                       Sunny Street Cafe
# 18    19                    Dogwood Social House
# 19    20                Panda Chinese Restaurant
# 20    21          O'Dell's Irish Pub & Ale House
# 21    22            St Louis Taco and Pita Grill
# 22    23                Shack Breakfast & Lunch
# 23    24                               Yen Ching
# 24    25                      Sarah's on Central
# 25    26                       Sauce on the Side
# 26    27            JB’s Smokehouse & Sports Bar
# 27    28            Phoenicia Mediterranean Deli
# 28    29  Ninja Japanese Sushi Bar & Steak House
# 29    30  Poor Richards Restaurant & Sports Club
# 30    31                      The Masked Chicken
# 31    32             Vallarta Mexican Restaurant
# 32    33               Joe Boccardi's Ristorante
# 33    34          Veritas Gateway to Food & Wine
# 34    35                        Babal-Hara Gyros
# 35    36                      Massa's Restaurant
# 36    37              Clancy's Irish Pub & Grill
# 37    38                       Super Smokers BBQ
# 38    39                         Michelle's Cafe
# 39    40                        Camila's Tex-Mex
# 40    41                         Boardwalk Pizza
# 41    42                          The Curry Club
# 42    43                  Fallon’s Grill and Tap
# 43    44                           Hunan Express
# 44    45                  Peppers Deli & Bar-B Q
# 45    46                               Mi Lupita
# 46    47                           Dewey's Pizza
# 47    48                Walnut Grill- Ellisville
# 48    49                            Pizzarelli's
# 49    50                            Chunmi Sushi
#
#                                               Address            Stars  \
# 0              17352 Manchester Rd Wildwood, MO 63038    4 star rating
# 1                    16721 Main St Wildwood, MO 63040  3.5 star rating
# 2              16524 Manchester Rd Wildwood, MO 63040  3.5 star rating
# 3            17253 New College Ave Wildwood, MO 63040  3.5 star rating
# 4            15939 Manchester Rd Ellisville, MO 63011    5 star rating
# 5            17209 New College Ave Wildwood, MO 63040  3.5 star rating
# 6                   505 Strecker Rd Ballwin, MO 63011    4 star rating
# 7                   2436 Taylor Rd Wildwood, MO 63040    4 star rating
# 8       40 Clarkson Wilson Ctr Chesterfield, MO 63017  4.5 star rating
# 9                  15480 Clayton Rd Ballwin, MO 63011  4.5 star rating
# 10                122A S Central Ave Eureka, MO 63025    4 star rating
# 11                 106 S Central Ave Eureka, MO 63025  4.5 star rating
# 12     1384 Clarkson Clayton Ctr Ellisville, MO 63011  4.5 star rating
# 13                11 Clarkson Rd Ellisville, MO 63011    4 star rating
# 14      15824 Fountains Plz Dr Chesterfield, MO 63017    4 star rating
# 15                2801 Fountain Pl Wildwood, MO 63040    4 star rating
# 16                    2408 Taylor Rd Grover, MO 63040  3.5 star rating
# 17  Dierbergs Town Ctr 2480 Taylor Road Wildwood, ...  3.5 star rating
# 18           15682 Manchester Rd Ellisville, MO 63011  2.5 star rating
# 19           17189 New College Ave Wildwood, MO 63040    4 star rating
# 20                 141 S Central Ave Eureka, MO 63025    4 star rating
# 21              15493 Manchester Rd Ballwin, MO 63011  4.5 star rating
# 22            14810 Clayton Rd Chesterfield, MO 63017  4.5 star rating
# 23             16584 Manchester Rd Wildwood, MO 63040  3.5 star rating
# 24                 127 S Central Ave Eureka, MO 63025    4 star rating
# 25            1637 Clarkson Rd Chesterfield, MO 63017  4.5 star rating
# 26                4900 Six Flags Rd Pacific, MO 63069  4.5 star rating
# 27              15344 Manchester Rd Ballwin, MO 63011  4.5 star rating
# 28            1737 Clarkson Rd Chesterfield, MO 63017  4.5 star rating
# 29            108 Hilltop Vlg Ctr Dr Eureka, MO 63025    3 star rating
# 30           15622 Manchester Rd Ellisville, MO 63011
# 31          16461 Village Plaza View Grover, MO 63040  3.5 star rating
# 32                   128 Boccardi Ln Eureka, MO 63025  3.5 star rating
# 33       15860 Fountain Plaza Dr Ellisville, MO 63017    4 star rating
# 34              15581 Manchester Rd Ballwin, MO 63011  4.5 star rating
# 35           15310 Manchester Rd Ellisville, MO 63011    4 star rating
# 36               40 Old State Rd Ellisville, MO 63021  3.5 star rating
# 37                   601 Stockell Dr Eureka, MO 63025  3.5 star rating
# 38                 104 S Central Ave Eureka, MO 63025  3.5 star rating
# 39       54 The Legends Pkwy Ste 152 Eureka, MO 63025    4 star rating
# 40           15638 Manchester Rd Ellisville, MO 63011  4.5 star rating
# 41            1635 Clarkson Rd Chesterfield, MO 63017  4.5 star rating
# 42           15850 Manchester Rd Ellisville, MO 63011    3 star rating
# 43     16445 Village Plaza View Dr Wildwood, MO 63011  3.5 star rating
# 44                32 Clarkson Rd Ellisville, MO 63011  4.5 star rating
# 45              15307 Manchester Rd Ballwin, MO 63011    4 star rating
# 46     1312 Clarkson Clayton Ctr Ellisville, MO 63011  4.5 star rating
# 47     1386 Clarkson Clayton Ctr Ellisville, MO 63011    3 star rating
# 48           15858 Manchester Rd Ellisville, MO 63011    4 star rating
# 49              15583 Manchester Rd Ballwin, MO 63011  4.5 star rating
#
#    Number_Reviews                                           Category
# 0     134 reviews      [American (Traditional), Burgers, Sandwiches]
# 1     118 reviews                             [Pizza, Italian, Bars]
# 2      82 reviews                                   [American (New)]
# 3     101 reviews                      [Burgers, Sports Bars, Pizza]
# 4     144 reviews                           [Mexican, Cocktail Bars]
# 5      88 reviews                        [Cafes, Breakfast & Brunch]
# 6      87 reviews                                   [American (New)]
# 7      75 reviews                [Thai, Noodles, Tapas/Small Plates]
# 8      36 reviews                 [Barbeque, Burgers, Chicken Wings]
# 9     295 reviews                              [Coffee & Tea, Salad]
# 10     60 reviews  [American (Traditional), Chicken Wings, Dive B...
# 11     23 reviews                                          [Mexican]
# 12     57 reviews                                      [Bars, Pizza]
# 13    106 reviews      [American (Traditional), Bars, Chicken Wings]
# 14    130 reviews                [Sports Bars, American (New), Pubs]
# 15       1 review                                         [Barbeque]
# 16     66 reviews                                          [Mexican]
# 17     67 reviews  [Breakfast & Brunch, Coffee & Tea, American (N...
# 18     32 reviews     [Sports Bars, American (Traditional), Karaoke]
# 19     18 reviews                                          [Chinese]
# 20    100 reviews              [American (Traditional), Pubs, Irish]
# 21    214 reviews                       [Mexican, Greek, Vegetarian]
# 22    220 reviews  [Breakfast & Brunch, Juice Bars & Smoothies, C...
# 23     36 reviews                                          [Chinese]
# 24     73 reviews            [Breakfast & Brunch, Cafes, Sandwiches]
# 25     78 reviews                      [Italian, Beer Bar, Desserts]
# 26      2 reviews                            [Sports Bars, Barbeque]
# 27    132 reviews                                    [Mediterranean]
# 28     67 reviews                [Sushi Bars, Japanese, Steakhouses]
# 29     61 reviews                                   [American (New)]
# 30              0                                    [Chicken Wings]
# 31     76 reviews                                          [Mexican]
# 32     92 reviews                       [Pizza, Italian, Sandwiches]
# 33     95 reviews                                   [American (New)]
# 34     61 reviews                [Greek, Mediterranean, Sports Bars]
# 35     61 reviews                                          [Italian]
# 36     56 reviews            [Burgers, American (Traditional), Pubs]
# 37    169 reviews                                         [Barbeque]
# 38     67 reviews                                            [Cafes]
# 39     47 reviews                                 [Tex-Mex, Mexican]
# 40    134 reviews                                            [Pizza]
# 41    102 reviews                                           [Indian]
# 42     33 reviews                              [Whiskey Bars, Irish]
# 43     29 reviews                                          [Chinese]
# 44     78 reviews                                  [Delis, Barbeque]
# 45    179 reviews                             [Mexican, Salad, Bars]
# 46    170 reviews                        [Pizza, Salad, Gluten-Free]
# 47    205 reviews              [American (Traditional), Sports Bars]
# 48     90 reviews                       [Pizza, Italian, Sandwiches]
# 49     61 reviews                             [Japanese, Sushi Bars]

# %%
yelp_urls
# Out:
# ['/biz/big-chief-roadhouse-wildwood-2?osq=Restaurants',
#  '/biz/benedettos-on-main-wildwood-2?osq=Restaurants',
#  '/biz/craft-wildwood?osq=Restaurants',
#  '/biz/wildwood-pub-and-grill-wildwood-3?osq=Restaurants',
#  '/biz/malinche-mexican-culinary-experience-ellisville?osq=Restaurants',
#  '/biz/letty-lous-cafe-wildwood?osq=Restaurants',
#  '/biz/parkside-grille-ballwin?osq=Restaurants',
#  '/biz/thai-bistro-wildwood?osq=Restaurants',
#  '/biz/the-stellar-hog-chesterfield?osq=Restaurants',
#  '/biz/the-wolf-ballwin?osq=Restaurants',
#  '/biz/chick-n-ellys-eureka?osq=Restaurants',
#  '/biz/hola-mexican-food-eureka?osq=Restaurants',
#  '/biz/the-crafty-chameleon-bar-ellisville?osq=Restaurants',
#  '/biz/mulligans-grill-ellisville-2?osq=Restaurants',
#  '/biz/the-corner-pub-and-grill-chesterfield?osq=Restaurants',
#  '/biz/wildwood-bbq-bash-wildwood?osq=Restaurants',
#  '/biz/el-maguey-grover?osq=Restaurants',
#  '/biz/sunny-street-cafe-wildwood-2?osq=Restaurants',
#  '/biz/dogwood-social-house-ellisville?osq=Restaurants',
#  '/biz/panda-chinese-restaurant-wildwood?osq=Restaurants',
#  '/biz/o-dells-irish-pub-and-ale-house-eureka?osq=Restaurants',
#  '/biz/st-louis-taco-and-pita-grill-ballwin?osq=Restaurants',
#  '/biz/shack-breakfast-and-lunch-chesterfield-5?osq=Restaurants',
#  '/biz/yen-ching-wildwood?osq=Restaurants',
#  '/biz/sarahs-on-central-eureka-2?osq=Restaurants',
#  '/biz/sauce-on-the-side-chesterfield-6?osq=Restaurants',
#  '/biz/jb-s-smokehouse-and-sports-bar-pacific?osq=Restaurants',
#  '/biz/phoenicia-mediterranean-deli-ballwin?osq=Restaurants',
#  '/biz/ninja-japanese-sushi-bar-and-steak-house-chesterfield?osq=Restaurants',
#  '/biz/poor-richards-restaurant-and-sports-club-eureka?osq=Restaurants',
#  '/biz/the-masked-chicken-ellisville?osq=Restaurants',
#  '/biz/vallarta-mexican-restaurant-grover?osq=Restaurants',
#  '/biz/joe-boccardis-ristorante-eureka?osq=Restaurants',
#  '/biz/veritas-gateway-to-food-and-wine-ellisville?osq=Restaurants',
#  '/biz/babal-hara-gyros-ballwin-3?osq=Restaurants',
#  '/biz/massas-restaurant-ellisville-3?osq=Restaurants',
#  '/biz/clancys-irish-pub-and-grill-ellisville-2?osq=Restaurants',
#  '/biz/super-smokers-bbq-eureka?osq=Restaurants',
#  '/biz/michelles-cafe-eureka?osq=Restaurants',
#  '/biz/camilas-tex-mex-eureka?osq=Restaurants',
#  '/biz/boardwalk-pizza-ellisville?osq=Restaurants',
#  '/biz/the-curry-club-chesterfield?osq=Restaurants',
#  '/biz/fallon-s-grill-and-tap-ellisville?osq=Restaurants',
#  '/biz/hunan-express-wildwood?osq=Restaurants',
#  '/biz/peppers-deli-and-bar-b-q-ellisville-2?osq=Restaurants',
#  '/biz/mi-lupita-ballwin?osq=Restaurants',
#  '/biz/deweys-pizza-ellisville-2?osq=Restaurants',
#  '/biz/walnut-grill-ellisville-ellisville?osq=Restaurants',
#  '/biz/pizzarellis-ellisville?osq=Restaurants',
#  '/biz/chunmi-sushi-ballwin?osq=Restaurants']

# %%
time.sleep(5)

# %%
# how to rewrite file

# import json

# filenm = "./static/yelp_data.json"

# with open(filenm,'r+') as file:
#     file.seek(0)
#     json.dump(yelp_info, file, indent = 4)

# %%
# import os
# #os.remove(filenm)


# rewrite_data = [yelp_info[0:2]]

# with open(filenm,'r+') as file:
#     file.seek(0)
#     json.dump(rewrite_data, file, indent = 4)

# %% [markdown]
# 2.	Create an API that calls your scrape function and stores the data when you call /scrape endpoint. The data you scrape should be viewable when you go to /all .

# %% [markdown]
# yelp.py is the flask app file for the website, yelp denied me access a few times

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3.	What is web scraping? Why is it helpful? Why is it sometimes in a legal grey area or just plain illegal?!
